# %%
airfoils=[]
for h in range(2,7):#starts with first number, but does not include stop number
    for i in range(1,6):
        for j in range(6,19):
            zero_j = str(j).zfill(2)
            airfoil = f"NACA{h}{i}{zero_j}"
            airfoils.append(airfoil)
            airfoils.append("oper")
            airfoils.append("iter 1000")
            airfoils.append("visc 160000")
            airfoils.append("pacc")
            airfoils.append(airfoil + ".txt")
            airfoils.append("")
            airfoils.append("aseq -6 5 1")
            airfoils.append("")
            airfoils.append("QUIT")
            airfoils.append("")
            airfoils.append(airfoil)
            airfoils.append("oper")
            airfoils.append("iter 1000")
            airfoils.append("visc 160000")
            airfoils.append("pacc")
            airfoils.append(airfoil + ".txt")
            airfoils.append("")
            airfoils.append("aseq 5 16 1")
            airfoils.append("")
            airfoils.append("QUIT")
            airfoils.append("")
         
            
            
"""str(k) turns k into a sting and .zfill(2) fills in zeros to the left to the 
   desired length of the string"""
for a in airfoils:
    print(a)
# Out:
# NACA2106
# oper
# iter 1000
# visc 160000
# pacc
# NACA2106.txt
#
# aseq -6 5 1
#
# QUIT
#
# NACA2106
# oper
# iter 1000
# visc 160000
# pacc
# NACA2106.txt
#
# aseq 5 16 1
#
# QUIT
#
# NACA2107
# oper
# iter 1000
# visc 160000
# pacc
# NACA2107.txt
#
# aseq -6 5 1
#
# QUIT
#
# NACA2107
# oper
# iter 1000
# visc 160000
# pacc
# NACA2107.txt
#
# aseq 5 16 1
#
# QUIT
#
# NACA2108
# oper
# iter 1000
# visc 160000
# pacc
# NACA2108.txt
#
# aseq -6 5 1
#
# QUIT
#
# NACA2108
# oper
# iter 1000
# visc 160000
# pacc
# NACA2108.txt
#
# aseq 5 16 1
#
# QUIT
#
# NACA2109
# oper
# iter 1000
# visc 160000
# pacc
# NACA2109.txt
#
# aseq -6 5 1
#
# QUIT
#
# NACA2109
# oper
# iter 1000
# visc 160000
# pacc
# NACA2109.txt
#
# aseq 5 16 1
#
# QUIT
#
# NACA2110
# oper
# iter 1000
# visc 160000
# pacc
# NACA2110.txt
#
# aseq -6 5 1
#
# QUIT
#
# NACA2110
# oper
# iter 1000
# visc 160000
# pacc
# NACA2110.txt
#
# aseq 5 16 1
#
# QUIT
#
# NACA2111
# oper
# iter 1000
# visc 160000
# pacc
# NACA2111.txt
#
# ...
